# %% [markdown]
# # Referências:
# https://python-visualization.github.io/folium/latest/#
#
# https://www.mockaroo.com/

# %%
! pip install folium pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 435.7 kB/s eta 0:00:27
#    ---------------------------------------- 0.0/11.5 MB 245.8 kB/s eta 0:00:47
#    ---------------------------------------- 0.1/11.5 MB 357.2 kB/s eta 0:00:32
#    ---------------------------------------- 0.1/11.5 MB 514.3 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/11.5 MB 514.3 kB/s eta 0:00:23
#     --------------------------------------- 0.2/11.5 MB 620.6 kB/s eta 0:00:19
#     --------------------------------------- 0.3/11.5 MB 768.0 kB/s eta 0:00:15
#    - -------------------------------------- 0.3/11.5 MB 824.9 kB/s eta 0:00:14
#    - -------------------------------------- 0.4/11.5 MB 881.6 kB/s eta 0:00:13
#    - -------------------------------------- 0.5/11.5 MB 1.0 MB/s eta 0:00:11
# ...

# %%
import folium

# %%
mapa  = folium.Map()

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Marker([-23.0058929484814, -43.31353964580872]).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
! pip install pandas

# %%
import pandas as pd

# %%
dados_geo = pd.read_json("MOCK_DATA.json")

# %%
dados_geo
# Out:
#          nome           cidade   latitude   longitude
# 0     Dorette  Juvisy-sur-Orge  48.691082    2.374132
# 1       Fiona           Khorol  49.783653   33.252663
# 2        Doug           Kovači  43.690835   18.794056
# 3      Cherye         Kalipare  -8.210598  112.470868
# 4      Ferris        Fengjiang  27.948308  109.599191
# ..        ...              ...        ...         ...
# 95    Cosette        Thepharak  13.765612  100.486253
# 96  Jacquette            Toyós  15.526267  -87.655647
# 97     Ramsay      Ts’khinvali  42.221460   43.964405
# 98     Karoly      Diyarb Najm  30.753222   31.442761
# 99   Dorothea          Roshal’  55.658370   39.865350
#
# [100 rows x 4 columns]

# %%
cidade =  dados_geo["cidade"]
latitude =  dados_geo["latitude"]
longitude = dados_geo["longitude"]

# %%
cidade
# Out:
# 0     48.691082
# 1     49.783653
# 2     43.690835
# 3     -8.210598
# 4     27.948308
#         ...
# 95    13.765612
# 96    15.526267
# 97    42.221460
# 98    30.753222
# 99    55.658370
# Name: latitude, Length: 100, dtype: float64

# %%
mapa2 = folium.Map()

# %%
for c, lat, lon in zip(cidade, latitude, longitude):
    folium.Marker([lat,lon], tooltip=c).add_to(mapa2)

# %%
mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import folium
import folium.plugins

import requests #Criando mapa

dados_geo = pd.read_json("br.json")


estado = 'RJ'
url = "https://servicodados.ibge.gov.br/api/v3/malhas/estados/{}?formato=application/vnd.geo+json".format(estado)
response = requests.get(url, verify=False)
geo_json_data = requests.get(url).json()

style =  {'fillColor': 'blue', #cor de preenchimento
            'color': 'red',#cor da linha de contorno
            'weight': 0.0, #espessura da linha
            }
#Opção


min_lon, max_lon = -45, -35
min_lat, max_lat = -25, -10

mapa3 = folium.Map(
    max_bounds=True,
    location=[-15.793889, -47.882778],
    zoom_start=4,
    min_lat=min_lat,
    max_lat=max_lat,
    min_lon=min_lon,
    max_lon=max_lon,)

folium.plugins.Geocoder().add_to(mapa3)

folium.GeoJson(geo_json_data, style_function=lambda x:style).add_to(mapa3)

cidade =  dados_geo["city"]
latitude =  dados_geo["lat"]
longitude = dados_geo["lng"]

for c, lat, lon in zip(cidade, latitude, longitude):
    folium.Marker([lat,lon], tooltip=c).add_to(mapa3)

mapa3
# Out:
# c:\Users\00661711722\Documents\Maps\.venv\Lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'servicodados.ibge.gov.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\00661711722\Documents\Maps\.venv\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# ...
